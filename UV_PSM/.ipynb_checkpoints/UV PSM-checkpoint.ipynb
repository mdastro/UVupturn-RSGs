# %% [markdown]
# # PREAMBLE
#
# #### Some prelimiar configurations are made here, before importing the libraries and starting the code.

# %% [markdown]
# ### Plot configs

# %%
plotpars = {'axes.labelsize': 18,
            'axes.linewidth': 1.,
            'figure.figsize': (7.,5.),
            'font.size': 20,
            'legend.frameon': True,
            'legend.framealpha': 0.85,
            'legend.edgecolor': 'black',
            'legend.loc': 'best',
            'legend.fontsize': 12,
            'mathtext.fontset': 'stixsans',
            'savefig.bbox': 'tight',
            'xtick.labelsize': 18,
            'ytick.labelsize': 18,
           }

plotpars_2cols = {'axes.labelsize': 18,
                  'axes.linewidth': 1.,
                  'figure.figsize': (15, 4.),
                  'font.size': 12,
                  'legend.frameon': True,
                  'legend.framealpha': 0.85,
                  'legend.edgecolor': 'black',
                  'legend.loc': 'best',
                  'legend.fontsize': 12,
                  'mathtext.fontset': 'stixsans',
                  'savefig.bbox': 'tight',
                  'xtick.labelsize': 15,
                  'ytick.labelsize': 15,
                 }

plotpars_3rows = {'axes.labelsize': 18,
                  'axes.linewidth': 1.,
                  'figure.figsize': (6, 9),
                  'font.size': 12,
                  'legend.frameon': True,
                  'legend.framealpha': 0.85,
                  'legend.edgecolor': 'black',
                  'legend.loc': 'best',
                  'legend.fontsize': 12,
                  'mathtext.fontset': 'stixsans',
                  'savefig.bbox': 'tight',
                  'xtick.labelsize': 15,
                  'ytick.labelsize': 15,
                 }

plotpars_3cols = {'axes.labelsize': 18,
                  'axes.linewidth': 1.,
                  'figure.figsize': (12, 3.5),
                  'font.size': 12,
                  'legend.frameon': True,
                  'legend.framealpha': 0.85,
                  'legend.edgecolor': 'black',
                  'legend.loc': 'best',
                  'legend.fontsize': 12,
                  'mathtext.fontset': 'stixsans',
                  'savefig.bbox': 'tight',
                  'xtick.labelsize': 15,
                  'ytick.labelsize': 15,
                 }

# %% [markdown]
# ### Functions

# %%
from sklearn.preprocessing import StandardScaler   as ss
from sklearn.neighbors     import NearestNeighbors as nn
import pandas as pd

def psm (reference_df, target_df, scaler=True):
    """
    
    :param reference_df: reference dataset, the one you will use as reference to match the second dataset.
    :param target_df:    dataset to be matched.
    :param scaler:       should it be scaled or not? how?
    :return: 
    """
    
    reference = reference_df.values
    target    = target_df.values
    header    = target_df.columns
    
    if scaler==True:
        scaler = ss()
    else:
        scaler.fit(reference)
        reference = scaler.transform(reference)
        target = scaler.transform(target)
    
    n_neighbors = 1
    neighbors = nn(n_neighbors=n_neighbors, algorithm='brute').fit(target)
    distances, indices = neighbors.kneighbors(reference)
    indices = indices.reshape(indices.shape[0]*n_neighbors)
    matched = pd.DataFrame(target[indices])
    matched.columns = header
    return (matched)

# %% [markdown]
# # Libraries

# %%
import numpy                as np
import pandas               as pd
import matplotlib.pyplot as plt
import seaborn              as sns
import os

# %% [markdown]
# # Dataset, paths, etc.

# %%
results_path = '../../LargeFilesResults/PSM_analysis/'

# %%
data_path = '../../Catalogue/Match07_smalldoubleclean_emlines.csv'

# %%
dataset = pd.read_csv(data_path)

# %%
uv_redseq_all = dataset[dataset['UV_CLASS_YI2011']!='RSF']

# %%
uv_redseq_retpassive = uv_redseq_all[uv_redseq_all['WHAN_CLASS']=='Retired/Passive']

# %%
uv_upturn = uv_redseq_retpassive[uv_redseq_retpassive['UV_CLASS_YI2011']=='UV_UPTURN']

# %%
uv_weak = uv_redseq_retpassive[uv_redseq_retpassive['UV_CLASS_YI2011']=='UV_WEAK']

# %% [markdown]
# # Let's check a few parameters before PSM

# %%
for i in uv_redseq_all.keys():
    print(i)
# Out:
# CATAID
# OBJID_SDSSDR7
# ALPHA_J2000
# DELTA_J2000
# KRON_RADIUS
# PETRO_RADIUS
# MAG_PETRO_u
# MAGERR_PETRO_u
# FLAGS_u
# MAG_PETRO_g
# MAGERR_PETRO_g
# FLAGS_g
# MAG_PETRO_r
# MAGERR_PETRO_r
# FLAGS_r
# MAG_PETRO_i
# MAGERR_PETRO_i
# FLAGS_i
# MAG_PETRO_z
# MAGERR_PETRO_z
# FLAGS_z
# MAG_PETRO_X
# MAGERR_PETRO_X
# FLAGS_X
# MAG_PETRO_Y
# MAGERR_PETRO_Y
# FLAGS_Y
# MAG_PETRO_J
# MAGERR_PETRO_J
# FLAGS_J
# MAG_PETRO_H
# MAGERR_PETRO_H
# FLAGS_H
# MAG_PETRO_K
# MAGERR_PETRO_K
# FLAGS_K
# FLAGS
# PSFMAG_R
# FIBERMAG_R
# FLAGS_R_SDSS
# PETRORAD_R
# PETROR90_R
# PETROR50_R
# PETROMAG_R
# MODELMAG_U
# MODELMAG_G
# MODELMAG_R
# MODELMAG_I
# MODELMAG_Z
# STATUS
# BEST_MAG_NUV
# BEST_MAGERR_NUV
# BEST_MAG_FUV
# BEST_MAGERR_FUV
# BEST_METHOD
# NMATCHUV
# NMATCHOPT
# NUVFLAG
# FUVFLAG
# NN_DIST
# NN_NMATCH4
# NN_MANY2ONE
# NN_SFLAGS_NUV
# NN_SFLAGS_FUV
# KCORR_FUV
# KCORR_NUV
# KCORR_U
# KCORR_G
# KCORR_R
# KCORR_I
# KCORR_Z
# KCORR_Y
# KCORR_J
# KCORR_H
# KCORR_K
# CHI2
# MASS
# INTSFH
# METS
# B300
# B1000
# SURVEY_CODE
# SURVEY_CLASS
# nbands
# S2N
# PPP
# logmstar
# dellogmstar
# logmoverl_i
# dellogmoverl_i
# logage
# dellogage
# logtau
# dellogtau
# logmintsfh
# dellogmintsfh
# logmremnants
# dellogmremnants
# metal
# delmetal
# extBV
# delextBV
# logLWage
# dellogLWage
# gminusi
# delgminusi
# uminusr
# deluminusr
# gminusi_stars
# uminusr_stars
# C_logM_ur
# C_logM_gi
# C_logM_eBV
# SPECID
# SURVEY_CODE_EMLINES
# SN
# D4000N
# D4000N_ERR
# SURVEY
# Z
# NQ
# PROB
# HB_FLUX_COMP
# HB_FLUX_ERR_COMP
# HB_EW_COMP
# HB_EW_ERR_COMP
# OIIIR_FLUX_COMP
# OIIIR_FLUX_ERR_COMP
# OIIIR_EW_COMP
# OIIIR_EW_ERR_COMP
# HA_FLUX_COMP
# HA_FLUX_ERR_COMP
# HA_EW_COMP
# HA_EW_ERR_COMP
# NIIR_FLUX_COMP
# NIIR_FLUX_ERR_COMP
# NIIR_EW_COMP
# NIIR_EW_ERR_COMP
# MAG_AB_FUV
# MAG_AB_NUV
# MAG_AB_U
# MAG_AB_G
# MAG_AB_R
# MAG_AB_I
# MAG_AB_Z
# MAG_AB_Y
# MAG_AB_J
# MAG_AB_H
# MAG_AB_K
# MAG_ABSOLUTE_FUV
# MAG_ABSOLUTE_NUV
# MAG_ABSOLUTE_U
# MAG_ABSOLUTE_G
# MAG_ABSOLUTE_R
# MAG_ABSOLUTE_I
# MAG_ABSOLUTE_Z
# MAG_ABSOLUTE_Y
# MAG_ABSOLUTE_J
# MAG_ABSOLUTE_H
# MAG_ABSOLUTE_K
# UV_CLASS_YI2011
# TYPE
# BPT_CLASS
# WHAN_CLASS

# %%
palette = ['#dfc27d', '#a6611a']

# %%
plt.rcParams.update(plotpars_3cols)
plt.subplot(1, 3, 1)
sns.kdeplot(uv_upturn['logmstar'], color=palette[1], label='UV upturn')
sns.kdeplot(uv_weak['logmstar'], color=palette[0], label='UV weak')
plt.legend(loc='upper left')
plt.xlabel(r"$\log M_{\star}$")

plt.subplot(1, 3, 2)
sns.kdeplot(uv_upturn['logage'], color=palette[1], label='UV upturn')
sns.kdeplot(uv_weak['logage'], color=palette[0], label='UV weak')
plt.legend(loc='upper left')
plt.xlabel(r"$\log t}$ (Gyr)")

plt.subplot(1, 3, 3)
sns.kdeplot(uv_upturn['B1000'], color=palette[1], label='UV upturn')
sns.kdeplot(uv_weak['B1000'], color=palette[0], label='UV weak')
plt.legend(loc='upper right')
plt.xlabel(r"B1000")

plt.show()

# %%
plt.rcParams.update(plotpars)
vplot1 = sns.catplot(x='WHAN_CLASS', y='logmstar', hue='UV_CLASS_YI2011', data=uv_redseq_retpassive, 
                     split=True, kind='violin', inner="quart", 
                     palette={"UV_UPTURN": palette[1], "UV_WEAK": palette[0]}, bw=.3, cut=1, linewidth=1., 
                     x_order=['UV_UPTURN','UV_WEAK'], legend_out=False, figsize=(20,4))
leg = vplot1.axes.flat[0].get_legend()
leg.set_title(None)
new_labels = ['UV weak', 'UV upturn']
for t, l in zip(leg.texts, new_labels): t.set_text(l)

plt.ylabel(r"$\log M_{\star}$")
plt.xlabel(r"")
plt.title(r"Before PSM")
plt.savefig(fname=os.path.join(results_path, 'psm_before_logmstar.png'))
plt.savefig(fname=os.path.join(results_path, 'psm_before_logmstar.pdf'))
plt.show()

# %%
plt.rcParams.update(plotpars)
vplot1 = sns.catplot(x='WHAN_CLASS', y='logage', hue='UV_CLASS_YI2011', data=uv_redseq_retpassive, 
                     split=True, kind='violin', inner="quart", 
                     palette={"UV_UPTURN": palette[1], "UV_WEAK": palette[0]}, bw=.3, cut=1, linewidth=1., 
                     x_order=['UV_UPTURN','UV_WEAK'], legend_out=False, figsize=(20,4))
leg = vplot1.axes.flat[0].get_legend()
leg.set_title(None)
new_labels = ['UV weak', 'UV upturn']
for t, l in zip(leg.texts, new_labels): t.set_text(l)

plt.ylabel(r"$\log t$ (Gyr)")
plt.xlabel(r"")
plt.title(r"Before PSM")
plt.savefig(fname=os.path.join(results_path, 'psm_before_logage.png'))
plt.savefig(fname=os.path.join(results_path, 'psm_before_logage.pdf'))

plt.show()

# %% [markdown]
# ## Creating sub dataframes only with the parameters to be matched (i.e. mass, redshift)

# %%
reference = uv_upturn.filter(items=['Z', 'logmstar'], axis=1)

# %%
target = uv_weak.filter(items=['Z', 'logmstar'], axis=1)

# %% [markdown]
# ## Running PSM

# %%
psm = psm(target_df=target, reference_df=reference)

# %%
print(psm)
# Out:
#           Z  logmstar
# 0   0.17015  10.85820
# 1   0.12357  10.48348
# 2   0.14638  10.66280
# 3   0.13693  10.29410
# 4   0.24746  11.25379
# ..      ...       ...
# 82  0.20081  11.21408
# 83  0.22105  11.15371
# 84  0.22552  10.98748
# 85  0.13527  10.58511
# 86  0.11764  10.45664
#
# [87 rows x 2 columns]

# %% [markdown]
# ## Recovering the original dataset after psm

# %%
uvwk_size     = uv_weak['Z'].values.size
uvwk_psm_size = psm['Z'].values.size

# %%
psm_id = ['CATAID']
for i, j in zip(range(uvwk_size), range(uvwk_psm_size)):
    if (uv_weak['Z'].iloc[i] == psm['Z'].iloc[j]) & (uv_weak['logmstar'].iloc[i] == psm['logmstar'].iloc[j]):
        psm_id.append(uv_weak['CATAID'].iloc[i])
#         print("redshifts are the same (following value should be zero):", 
#               (uv_weak['Z'].iloc[i] - psm['Z'].iloc[j]))
    else:
#         print("redshifts should not be the same (following value should not be zero):", 
#               (uv_weak['Z'].iloc[i]- psm['Z'].iloc[j]))    
        continue

# %%
psm_id = ['CATAID']
uvwk_revert_idx = []
for i in range(uvwk_size):
    for j in range(uvwk_psm_size):
        if psm['Z'].iloc[j] == uv_weak['Z'].iloc[i]:
            if psm['logmstar'].iloc[j] == uv_weak['logmstar'].iloc[i]:
                psm_id.append(uv_weak['CATAID'].iloc[i])
                uvwk_revert_idx.append(i)
#                 print(psm['Z'].iloc[j], uv_weak['Z'].iloc[i])
#                 print(psm['logmstar'].iloc[j], uv_weak['logmstar'].iloc[i])
        else:
            continue

# %%
len(psm_id)
# Out:
# 88

# %%
psm_id
# Out:
# ['CATAID',
#  594913,
#  601015,
#  611561,
#  611561,
#  611561,
#  611561,
#  623746,
#  14926,
#  14926,
#  14926,
#  15040,
#  250615,
#  250615,
#  267010,
#  272688,
#  278774,
#  299132,
#  299132,
#  319765,
#  319765,
#  319765,
#  319765,
#  319765,
#  323278,
#  323278,
#  323278,
#  343316,
#  348010,
#  382082,
#  382082,
#  382082,
#  397040,
#  397130,
#  419476,
#  419476,
#  3860408,
#  3888446,
#  3888446,
#  31592,
#  31592,
#  48561,
#  48561,
#  54640,
#  54644,
#  54644,
#  63657,
#  64081,
#  64081,
#  64158,
#  78967,
#  84295,
#  84295,
#  85679,
#  85679,
#  91600,
#  91600,
#  98073,
#  105613,
#  106766,
#  106766,
#  106766,
#  106766,
#  107237,
#  107809,
#  534813,
#  534813,
#  535469,
#  537184,
#  560509,
#  568249,
#  568249,
#  568249,
#  143221,
#  143819,
#  143894,
#  143894,
#  144798,
#  145244,
#  145244,
#  145646,
#  239670,
#  239670,
#  240001,
#  240001,
#  585358,
#  585358,
#  585358]

# %%
uvwk_revert_idx = np.unique(np.array(uvwk_revert_idx))
uvwk_revert_idx
# Out:
# array([  0,   1,   4,   6,   7,   8,  12,  13,  15,  17,  20,  21,  22,
#         23,  24,  27,  31,  32,  33,  49,  52,  59,  61,  63,  64,  66,
#         67,  68,  71,  72,  73,  74,  76,  78,  79,  80,  81,  82,  84,
#         86,  89,  90,  97,  98,  99, 100, 101, 102, 114, 115, 117])

# %%
uv_weak_psmed = uv_weak.iloc[list(uvwk_revert_idx)]

# %%
uv_weak_psmed
# Out:
#         CATAID       OBJID_SDSSDR7  ALPHA_J2000  DELTA_J2000  KRON_RADIUS  \
# 122     594913  588848899931242710     222.3814    -0.031320         3.50
# 204     601015  588848900431282478     138.2987     0.273487         3.50
# 398     611561  588848900451860633     185.2660     0.306512         3.50
# 803     623746  588848900969005194     140.2268     0.735974         3.50
# 967      14926  588848901000986793     213.3015     0.694600         3.50
# 982      15040  588848901001248951     213.8470     0.838207         3.50
# 1649    250615  587726015084364012     215.2646     2.054914         3.50
# 2521    267010  587726016160268470     220.2140     2.799421         3.50
# 2709    272688  587726031175024794     180.5456     1.441575         3.50
# 2833    278774  587726031691383171     133.6441     0.848827         3.50
# 3401    299132  587726031730704588     223.4878     1.318822         3.50
# 3684    319765  587726032264167665     215.7386     1.828741         3.50
# 3927    323278  587726032764076368     131.2087     1.605183         3.76
# 4238    343316  587726032802808097     219.7191     2.112215         3.93
# 4376    348010  587726033304748280     139.9142     2.236177         3.50
# 5148    382082  587727944027472291     135.2337     1.987620         3.50
# 5275    397040  587728307495174291     176.4559     1.446693         3.50
# 5282    397130  587728307495370970     176.8048     1.443358         3.50
# 5353    419476  587728879260467351     140.2058     2.771706         3.50
# 7551   3860408  588010930295800112     133.4381    -1.932173         3.50
# 7654   3888446  588010930834440524     137.5365    -1.608999         4.00
# 7935     31592  587722981740249158     180.3261    -1.104882         3.50
# 8342     48561  587722982293373245     217.5809    -0.641767         3.50
# 8631     54640  587722982813335695     178.9574    -0.273337         3.50
# 8633     54644  587722982813335728     178.8907    -0.381827         3.75
# 8901     63657  587722982829850849     216.6447    -0.276562         3.50
# 8950     64081  587722982830506004     218.0613    -0.283828         3.50
# 8968     64158  587722982830637234     218.3593    -0.236446         4.49
# 9483     78967  587722983367901478     219.3216     0.184759         3.62
# 9645     84295  587722983886291044     177.0550     0.602053         3.50
# 9746     85679  587722983889109168     183.5031     0.522785         3.50
# 9815     91600  587722983901888845     212.7210     0.475188         3.50
# 10138    98073  587722984422703244     176.0345     0.986652         3.50
# 10271   105613  587722984438759728     212.7840     1.005131         3.50
# 10443   106766  587722984440725745     217.2133     0.968631         3.50
# 10493   107237  587722984441512111     218.9876     0.985500         3.50
# 10571   107809  587722984443150583     222.7452     0.934638         3.50
# 10613   534813  588848898836856954     175.2487    -0.872477         3.50
# 10673   535469  588848898838036689     177.8970    -0.939568         3.50
# 10801   537184  588848898840854711     184.4557    -0.894597         3.50
# 11313   560509  588848899376021590     180.4509    -0.474925         3.50
# 11499   568249  588848899390833018     214.3070    -0.618784         3.50
# 12377   143221  587724650865360999     174.7135    -1.342402         3.50
# 12435   143819  587724650866606254     177.6269    -1.347968         3.50
# 12446   143894  587724650866802827     178.0318    -1.280064         3.50
# 12517   144798  587724650868310153     181.4795    -1.397236         3.71
# 12545   145244  587724650869227683     183.6240    -1.323914         3.50
# 12591   145646  587724650870079712     185.5760    -1.271044         3.65
# 14085   239670  587726014548934888     218.6060     1.636215         3.50
# 14135   240001  587726014549590290     220.0579     1.619308         3.55
# 14322   585358  588848899913744639     182.4603    -0.123035         3.50
#
#        PETRO_RADIUS  MAG_PETRO_u  MAGERR_PETRO_u  FLAGS_u  MAG_PETRO_g  ...  \
# 122            4.62      20.4692          0.0377        2      18.8379  ...
# 204            5.28      20.7083          0.0683        2      19.1439  ...
# 398            4.62      21.4321          0.0773        2      19.1295  ...
# 803            5.28      21.2805          0.1015        0      19.0778  ...
# 967            4.62      20.9827          0.0636        0      19.1201  ...
# 982            4.62      20.5331          0.0484        2      19.1585  ...
# 1649           5.28      20.7861          0.0617        2      19.4349  ...
# 2521           4.62      20.9457          0.0585        2      19.2399  ...
# 2709           5.28      20.8145          0.0964        0      19.3625  ...
# 2833           4.62      21.4801          0.0593        2      19.6425  ...
# 3401           4.62      21.8738          0.1740        0      19.4803  ...
# 3684           4.62      21.0544          0.0842        2      19.3564  ...
# 3927           5.94      19.8254          0.0563        2      19.2412  ...
# 4238           4.62      99.0000         99.0000        2      19.5884  ...
# 4376           5.28      21.2008          0.0805        0      19.1132  ...
# 5148           4.62      23.8130          1.1074        0      19.9728  ...
# 5275           4.62      21.3833          0.0786        2      18.9567  ...
# 5282           4.62      22.2769          0.1988        2      19.7238  ...
# 5353           4.62      21.8049          0.1118        2      19.3431  ...
# 7551           4.62      20.4473          0.0745        2      18.2427  ...
# 7654           5.94      20.2285          0.0900        3      18.8433  ...
# 7935           5.28      20.2085          0.1200        2      19.0635  ...
# 8342           3.50      20.2153          0.0457        3      19.2399  ...
# 8631           4.62      20.5750          0.1478        2      18.8513  ...
# 8633           5.28      21.5801          0.5637        2      19.6577  ...
# 8901           4.62      21.2721          0.0921        0      19.2785  ...
# 8950           3.96      23.5155          0.7130        3      20.0185  ...
# 8968           3.50      19.1647          0.0463        3      18.7086  ...
# 9483           4.62      22.0815          0.1862        3      19.9219  ...
# 9645           4.62      21.4331          0.1450        2      19.2967  ...
# 9746           5.28      22.8092          0.4541        2      19.7221  ...
# 9815           5.28      21.1688          0.1041        2      19.0335  ...
# 10138          5.28      21.3523          0.1437        2      19.9238  ...
# 10271          3.96      20.9684          0.0658        3      18.9546  ...
# 10443          4.62      20.8931          0.0510        0      18.9895  ...
# 10493          4.62      20.5285          0.0443        2      18.9303  ...
# 10571          5.28      21.1497          0.0727        2      19.3808  ...
# 10613          4.62      20.6106          0.0524        2      18.9640  ...
# 10673          4.62      21.7843          0.0957        0      19.9149  ...
# 10801          4.62      20.5320          0.0499        2      18.9415  ...
# 11313          4.62      20.6162          0.0331        2      19.1642  ...
# 11499          5.28      21.7858          0.1914        3      19.6094  ...
# 12377          3.96      20.4876          0.0375        2      19.0706  ...
# 12435          5.28      99.0000         99.0000        0      19.9782  ...
# 12446          4.62      22.0575          0.1747        2      19.1997  ...
# 12517          4.62      21.8144          0.1299        2      19.4113  ...
# 12545          4.62      20.9746          0.0587        2      19.3470  ...
# 12591          5.28      20.5001          0.0599        2      19.1995  ...
# 14085          4.62      21.6036          0.1446        0      19.0099  ...
# 14135          4.62      21.1631          0.0964        0      19.7233  ...
# 14322          4.62      21.0827          0.0500        2      19.6764  ...
#
#        MAG_ABSOLUTE_I  MAG_ABSOLUTE_Z  MAG_ABSOLUTE_Y  MAG_ABSOLUTE_J  \
# 122        -21.929809      -22.346751      -21.905216      -22.018757
# 204        -22.015853      -22.373200      -21.834502      -21.936577
# 398        -22.168942      -22.383982      -21.976433      -22.044531
# 803        -22.267569      -22.654730      -22.018936      -22.254960
# 967        -22.500084      -22.844510      -22.415620      -22.597007
# 982        -21.300421      -21.703081      -21.092417      -21.140999
# 1649       -21.993622      -22.392895      -21.835008      -22.050784
# 2521       -20.222474      -20.573465      -20.032761      -19.929279
# 2709       -21.927955      -22.257915      -21.866924      -22.041726
# 2833       -22.040999      -22.233231      -21.758520      -21.870338
# 3401       -21.528108      -21.927600      -21.385442      -21.519075
# 3684       -22.358841      -22.721751      -22.433306      -22.635917
# 3927       -22.774204      -23.219815      -22.926291      -23.075414
# 4238       -22.215512      -22.583377      -22.175277      -22.287413
# 4376       -20.507624      -20.878228      -20.528524      -20.572185
# 5148       -22.388163      -22.721066      -22.422514      -22.623000
# 5275       -22.259918      -22.537076      -22.075199      -22.166983
# 5282       -22.551367      -22.956952      -22.561116      -22.767901
# 5353       -21.640331      -22.073559      -21.563678      -21.715556
# 7551       -21.679988      -22.062218      -21.584383      -21.535259
# 7654       -23.041995      -23.413789      -23.050615      -23.226219
# 7935       -21.210865      -21.507734      -21.151810      -21.226535
# 8342       -22.873493      -23.278105      -22.857629      -23.010936
# 8631       -21.182908      -21.552211      -21.135393      -21.166888
# 8633       -22.877920      -23.442788      -22.892134      -23.093246
# 8901       -22.267365      -22.713929      -22.293799      -22.472242
# 8950       -23.124887      -23.593296      -23.145321      -23.332601
# 8968       -20.531976      -20.901290      -22.162296      -22.223892
# 9483       -22.407640      -22.818969      -22.546740      -22.786597
# 9645       -20.506518      -20.954372      -20.466769      -20.419803
# 9746       -23.322960      -23.758968      -23.193492      -23.350045
# 9815       -21.815675      -22.325081      -21.850330      -22.108377
# 10138      -22.434317      -22.813952      -22.408163      -22.535558
# 10271      -22.257217      -22.685165      -22.260779      -22.364699
# 10443      -22.343847      -22.669700      -22.199284      -22.315540
# 10493      -21.434917      -21.868081      -21.511176      -21.608320
# 10571      -21.255739      -21.690010      -21.152812      -21.212910
# 10613      -22.218690      -22.617866      -22.042898      -22.155933
# 10673      -20.594801      -21.030254      -20.725143      -20.804511
# 10801      -21.485869      -21.930494      -21.326137      -21.364240
# 11313      -22.216569      -22.574695      -22.013164      -22.116719
# 11499      -22.584743      -22.961598      -22.498875      -22.572010
# 12377      -21.703182      -22.126053      -21.685269      -21.799650
# 12435      -22.548549      -22.940474      -22.640992      -22.792268
# 12446      -21.527134      -21.942439      -21.470327      -21.541773
# 12517      -22.003763      -22.313593      -21.787531      -21.901222
# 12545      -21.118006      -21.548663      -21.101357      -21.111181
# 12591      -22.577913      -23.007653      -22.281921      -22.298974
# 14085      -21.967333      -22.365537      -21.799849      -21.887906
# 14135      -23.064314      -23.550886      -23.144908      -23.260421
# 14322      -22.151928      -22.552546      -22.012211      -22.244721
#
#        MAG_ABSOLUTE_H  MAG_ABSOLUTE_K  UV_CLASS_YI2011  TYPE  BPT_CLASS  \
# 122        -21.694539      -21.484908          UV_WEAK     3        NaN
# 204        -21.720451      -21.671633          UV_WEAK     3        NaN
# 398        -21.674396      -21.735826          UV_WEAK     3      LINER
# 803        -21.952036      -21.752979          UV_WEAK     3        NaN
# 967        -22.374534      -22.431652          UV_WEAK     3      LINER
# 982        -20.911043      -20.636452          UV_WEAK     3        NaN
# 1649       -21.674063      -21.680437          UV_WEAK     3        NaN
# 2521       -19.627911      -19.227116          UV_WEAK     3        NaN
# 2709       -21.824038      -21.762313          UV_WEAK     3  Composite
# 2833       -21.512323      -21.582000          UV_WEAK     3        NaN
# 3401       -21.180021      -21.119260          UV_WEAK     3      LINER
# 3684       -22.362152      -22.412386          UV_WEAK     3        NaN
# 3927       -22.914322      -22.955496          UV_WEAK     3        NaN
# 4238       -21.941613      -21.930788          UV_WEAK     3  Composite
# 4376       -20.300342      -20.008419          UV_WEAK     3      LINER
# 5148       -22.404450      -22.449853          UV_WEAK     3      LINER
# 5275       -21.786641      -21.785382          UV_WEAK     3  Composite
# 5282       -22.595680      -22.733307          UV_WEAK     3        NaN
# 5353       -21.427047      -21.215568          UV_WEAK     3        NaN
# 7551       -21.302388      -20.908431          UV_WEAK     3      LINER
# 7654       -22.903674      -22.922611          UV_WEAK     3        NaN
# 7935        61.344395      -20.687561          UV_WEAK     3      LINER
# 8342       -22.839313      -22.752851          UV_WEAK     3        NaN
# 8631       -20.887398      -20.588423          UV_WEAK     3         SF
# 8633       -22.957022      -23.092055          UV_WEAK     3        NaN
# 8901       -22.228966      -22.156186          UV_WEAK     3  Composite
# 8950       -23.183393      -23.243444          UV_WEAK     3        NaN
# 8968       -21.740109      -20.641606          UV_WEAK     3        NaN
# 9483       -22.635800      -22.809110          UV_WEAK     3  Composite
# 9645       -20.089358      -19.833460          UV_WEAK     3        NaN
# 9746       -23.222966      -23.421651          UV_WEAK     3        NaN
# 9815       -22.057071      -22.131266          UV_WEAK     3      LINER
# 10138      -22.301634      -22.502646          UV_WEAK     3  Composite
# 10271      -22.067486      -22.003195          UV_WEAK     3        NaN
# 10443      -22.050909      -22.041516          UV_WEAK     3  Composite
# 10493      -21.337936      -21.172109          UV_WEAK     3        NaN
# 10571      -20.923834      -20.741061          UV_WEAK     3  Composite
# 10613      -21.905118      -21.709499          UV_WEAK     3  Composite
# 10673      -20.599934      -20.377991          UV_WEAK     3      LINER
# 10801      -21.187609      -20.957371          UV_WEAK     3  Composite
# 11313      -21.898375      -21.843778          UV_WEAK     3  Composite
# 11499      -22.440989      -22.466459          UV_WEAK     3        NaN
# 12377      -21.495853      -21.322178          UV_WEAK     3      LINER
# 12435      -22.511483      -22.691632          UV_WEAK     3        NaN
# 12446      -21.126740      -21.014139          UV_WEAK     3  Composite
# 12517      -21.674313      -21.617148          UV_WEAK     3  Composite
# 12545      -20.861067      -20.652607          UV_WEAK     3      LINER
# 12591      -22.133300      -22.026224          UV_WEAK     3  Composite
# 14085      -21.589930      -21.403236          UV_WEAK     3        NaN
# 14135      -23.139547      -23.303878          UV_WEAK     3        NaN
# 14322      -22.001791      -21.977511          UV_WEAK     3  Composite
#
#             WHAN_CLASS
# 122    Retired/Passive
# 204    Retired/Passive
# 398    Retired/Passive
# 803    Retired/Passive
# 967    Retired/Passive
# 982    Retired/Passive
# 1649   Retired/Passive
# 2521   Retired/Passive
# 2709   Retired/Passive
# 2833   Retired/Passive
# 3401   Retired/Passive
# 3684   Retired/Passive
# 3927   Retired/Passive
# 4238   Retired/Passive
# 4376   Retired/Passive
# 5148   Retired/Passive
# 5275   Retired/Passive
# 5282   Retired/Passive
# 5353   Retired/Passive
# 7551   Retired/Passive
# 7654   Retired/Passive
# 7935   Retired/Passive
# 8342   Retired/Passive
# 8631   Retired/Passive
# 8633   Retired/Passive
# 8901   Retired/Passive
# 8950   Retired/Passive
# 8968   Retired/Passive
# 9483   Retired/Passive
# 9645   Retired/Passive
# 9746   Retired/Passive
# 9815   Retired/Passive
# 10138  Retired/Passive
# 10271  Retired/Passive
# 10443  Retired/Passive
# 10493  Retired/Passive
# 10571  Retired/Passive
# 10613  Retired/Passive
# 10673  Retired/Passive
# 10801  Retired/Passive
# 11313  Retired/Passive
# 11499  Retired/Passive
# 12377  Retired/Passive
# 12435  Retired/Passive
# 12446  Retired/Passive
# 12517  Retired/Passive
# 12545  Retired/Passive
# 12591  Retired/Passive
# 14085  Retired/Passive
# 14135  Retired/Passive
# 14322  Retired/Passive
#
# [51 rows x 164 columns]

# %%
plt.rcParams.update(plotpars)

plt.scatter(y=uv_upturn['logmstar'], x=uv_upturn['Z'], c=palette[1])
plt.scatter(y=uv_weak['logmstar'], x=uv_weak['Z'], c=palette[0])
plt.scatter(y=uv_weak_psmed['logmstar'], x=uv_weak_psmed['Z'], c='red')
plt.xlabel("z")
plt.ylabel(r"$\log M_{\star}$")
plt.show()

# %%
uv_redseq_psmed = pd.concat([uv_upturn, uv_weak_psmed])

# %%
uv_redseq_psmed
# Out:
#        CATAID       OBJID_SDSSDR7  ALPHA_J2000  DELTA_J2000  KRON_RADIUS  \
# 126    594994  588848899931439415     222.9286    -0.152468         3.50
# 188    600232  588848900429578535     134.3863     0.325479         3.50
# 278    609836  588848900448452756     177.4558     0.352174         3.50
# 289    610293  588848900449370284     179.6213     0.360711         3.50
# 307    610441  588848900449632462     180.2054     0.211046         3.50
# ...       ...                 ...          ...          ...          ...
# 12545  145244  587724650869227683     183.6240    -1.323914         3.50
# 12591  145646  587724650870079712     185.5760    -1.271044         3.65
# 14085  239670  587726014548934888     218.6060     1.636215         3.50
# 14135  240001  587726014549590290     220.0579     1.619308         3.55
# 14322  585358  588848899913744639     182.4603    -0.123035         3.50
#
#        PETRO_RADIUS  MAG_PETRO_u  MAGERR_PETRO_u  FLAGS_u  MAG_PETRO_g  ...  \
# 126            4.62      20.6537          0.0385        2      19.4048  ...
# 188            4.62      22.1271          0.1172        0      19.6814  ...
# 278            4.62      21.1312          0.0543        2      19.1966  ...
# 289            5.28      21.0113          0.0503        0      19.4856  ...
# 307            4.62      99.0000         99.0000        2      19.6212  ...
# ...             ...          ...             ...      ...          ...  ...
# 12545          4.62      20.9746          0.0587        2      19.3470  ...
# 12591          5.28      20.5001          0.0599        2      19.1995  ...
# 14085          4.62      21.6036          0.1446        0      19.0099  ...
# 14135          4.62      21.1631          0.0964        0      19.7233  ...
# 14322          4.62      21.0827          0.0500        2      19.6764  ...
#
#        MAG_ABSOLUTE_I  MAG_ABSOLUTE_Z  MAG_ABSOLUTE_Y  MAG_ABSOLUTE_J  \
# 126        -22.029465      -22.442282      -22.047424      -22.231922
# 188        -21.315083      -21.715293      -21.262389      -21.368953
# 278        -21.563402      -21.957876      -21.504438      -21.593912
# 289        -21.092482      -21.392768       60.306025      -21.016597
# 307        -22.926391      -23.394366       58.932030      -23.289495
# ...               ...             ...             ...             ...
# 12545      -21.118006      -21.548663      -21.101357      -21.111181
# 12591      -22.577913      -23.007653      -22.281921      -22.298974
# 14085      -21.967333      -22.365537      -21.799849      -21.887906
# 14135      -23.064314      -23.550886      -23.144908      -23.260421
# 14322      -22.151928      -22.552546      -22.012211      -22.244721
#
#        MAG_ABSOLUTE_H  MAG_ABSOLUTE_K  UV_CLASS_YI2011  TYPE  BPT_CLASS  \
# 126        -21.964594      -21.916374        UV_UPTURN     3        NaN
# 188        -21.091291      -20.952605        UV_UPTURN     3      LINER
# 278        -21.337500      -21.125730        UV_UPTURN     3      LINER
# 289        -20.755046      -20.663166        UV_UPTURN     3      LINER
# 307        -23.082883      -23.258085        UV_UPTURN     3        NaN
# ...               ...             ...              ...   ...        ...
# 12545      -20.861067      -20.652607          UV_WEAK     3      LINER
# 12591      -22.133300      -22.026224          UV_WEAK     3  Composite
# 14085      -21.589930      -21.403236          UV_WEAK     3        NaN
# 14135      -23.139547      -23.303878          UV_WEAK     3        NaN
# 14322      -22.001791      -21.977511          UV_WEAK     3  Composite
#
#             WHAN_CLASS
# 126    Retired/Passive
# 188    Retired/Passive
# 278    Retired/Passive
# 289    Retired/Passive
# 307    Retired/Passive
# ...                ...
# 12545  Retired/Passive
# 12591  Retired/Passive
# 14085  Retired/Passive
# 14135  Retired/Passive
# 14322  Retired/Passive
#
# [138 rows x 164 columns]

# %%
plt.rcParams.update(plotpars)
vplot1 = sns.catplot(x='WHAN_CLASS', y='logmstar', hue='UV_CLASS_YI2011', data=uv_redseq_psmed, 
                     split=True, kind='violin', inner="quart", 
                     palette={"UV_UPTURN": palette[0], "UV_WEAK": palette[1]}, bw=.3, cut=1, linewidth=1., 
                     x_order=['UV_UPTURN','UV_WEAK'], legend_out=False, figsize=(20,4))
leg = vplot1.axes.flat[0].get_legend()
leg.set_title(None)
new_labels = ['UV weak', 'UV upturn']
for t, l in zip(leg.texts, new_labels): t.set_text(l)

plt.ylabel(r"$\log M_{\star}$")
plt.xlabel(r"")
plt.title(r"After PSM")
plt.savefig(fname=os.path.join(results_path, 'psm_after_logmstar.png'))
plt.savefig(fname=os.path.join(results_path, 'psm_after_logmstar.pdf'))

plt.show()

# %%
plt.rcParams.update(plotpars)
vplot1 = sns.catplot(x='WHAN_CLASS', y='logage', hue='UV_CLASS_YI2011', data=uv_redseq_psmed, 
                     split=True, kind='violin', inner="quart", 
                     palette={"UV_UPTURN": palette[0], "UV_WEAK": palette[1]}, bw=.3, cut=1, linewidth=1., 
                     x_order=['UV_UPTURN','UV_WEAK'], legend_out=False, figsize=(20,4))
leg = vplot1.axes.flat[0].get_legend()
leg.set_title(None)
new_labels = ['UV weak', 'UV upturn']
for t, l in zip(leg.texts, new_labels): t.set_text(l)

plt.ylabel(r"$\log t$ (Gyr)")
plt.xlabel(r"")
plt.title(r"After PSM")
plt.savefig(fname=os.path.join(results_path, 'psm_after_logage.png'))
plt.savefig(fname=os.path.join(results_path, 'psm_after_logage.pdf'))
plt.show()

# %%
plt.rcParams.update(plotpars)
vplot1 = sns.catplot(x='WHAN_CLASS', y='Z', hue='UV_CLASS_YI2011', data=uv_redseq_retpassive, 
                     split=True, kind='violin', inner="quart", 
                     palette={"UV_UPTURN": palette[1], "UV_WEAK": palette[0]}, bw=.3, cut=1, linewidth=1., 
                     x_order=['UV_UPTURN','UV_WEAK'], legend_out=False, figsize=(20,4))
leg = vplot1.axes.flat[0].get_legend()
leg.set_title(None)
new_labels = ['UV weak', 'UV upturn']
for t, l in zip(leg.texts, new_labels): t.set_text(l)

plt.ylabel(r"z")
plt.xlabel(r"")
plt.title(r"Before PSM")
plt.savefig(fname=os.path.join(results_path, 'psm_before_z.png'))
plt.savefig(fname=os.path.join(results_path, 'psm_before_z.pdf'))
plt.show()

# %%
plt.rcParams.update(plotpars)
vplot1 = sns.catplot(x='WHAN_CLASS', y='Z', hue='UV_CLASS_YI2011', data=uv_redseq_psmed, 
                     split=True, kind='violin', inner="quart", 
                     palette={"UV_UPTURN": palette[1], "UV_WEAK": palette[0]}, bw=.3, cut=1, linewidth=1., 
                     x_order=['UV_UPTURN','UV_WEAK'], legend_out=False, figsize=(20,4))
leg = vplot1.axes.flat[0].get_legend()
leg.set_title(None)
new_labels = ['UV weak', 'UV upturn']
for t, l in zip(leg.texts, new_labels): t.set_text(l)

plt.ylabel(r"z")
plt.xlabel(r"")
plt.title(r"After PSM")
plt.savefig(fname=os.path.join(results_path, 'psm_after_z.png'))
plt.savefig(fname=os.path.join(results_path, 'psm_after_z.pdf'))
plt.show()
