# %% [markdown]
# # Packages

# %%
import numpy             as np
import pandas            as pd
import matplotlib.pyplot as plt
import seaborn           as sns
import os

# %% [markdown]
# # Paths

# %%
outputs_path = '../../LargeFilesResults/SEDFitting/'
# new_dir = os.mkdir(os.path.join(outputs_path, 'Analyses_mdegrees'))

# %% [markdown]
# # Reading the outputs

# %%
out_m150 = pd.read_csv(os.path.join(outputs_path, 'Batch150/outputs_ppxf_150_4350.csv'))
out_m200 = pd.read_csv(os.path.join(outputs_path, 'Batch200/outputs_ppxf_200_4350.csv'))
out_m230 = pd.read_csv(os.path.join(outputs_path, 'Batch230/outputs_ppxf_230_4350.csv'))

# %% [markdown]
# # Merging them into a single dataframe

# %%
out_m230.columns = ['CATAID', 'Z', '<logAge>_m230', '<[M/H]>_m230', 'MASS2LIGHT_R_m230', 'S2N_runz', 'CHI2_PPXF_m230']

# %%
mega_dataframe = out_m150.merge(out_m200, how='inner', on=['CATAID', 'Z'], suffixes=('_m150', '_m200'),
                                validate='one_to_one').merge(out_m230, how='inner', on=['CATAID', 'Z'], 
                                                             validate='one_to_one')

# %%
mega_dataframe.to_csv(os.path.join(outputs_path, 'summary_batches.csv'))

# %%
mega_dataframe
# Out:
#     CATAID        Z  <logAge>_m150  <[M/H]>_m150  MASS2LIGHT_R_m150  \
# 0   594994  0.17168       9.884191     -0.195884           3.088597
# 1   600232  0.15761       9.836326     -0.204140           2.705681
# 2   609836  0.13537       9.875975     -0.413657           2.648012
# 3   610293  0.13949       9.740460     -0.721777           1.167613
# 4   610441  0.25032       9.790523     -0.281246           2.307532
# 5   617899  0.12310       9.700070     -0.676638           0.962645
# 6   619222  0.21629       9.785438     -0.278004           2.279788
# 7   619575  0.17986       9.813153     -0.472584           2.158551
# 8     6840  0.19309       9.810833     -0.576387           1.806109
# 9    14922  0.16361       9.851407     -0.198050           2.826770
# 10   17387  0.14849       9.818767     -0.218925           2.562470
# 11   22885  0.17948       9.882547     -0.195723           3.075691
# 12   23262  0.11194       9.866692     -0.385444           1.973673
# 13   23618  0.15898       9.905283     -0.231875           3.170704
# 14  231048  0.18462       9.852470     -0.196457           2.837227
# 15  271394  0.20726       9.807562     -0.359991           2.328938
# 16  272306  0.15779       9.909798     -0.206244           3.277349
# 17  273046  0.18509       9.912116     -0.196425           3.321634
# 18  273844  0.07801       9.660065     -0.743818           0.839156
# 19  289261  0.17460       9.877423     -0.195842           3.034228
# 20  289379  0.18570       9.892768     -0.195752           3.159706
# 21  297022  0.27502       9.808419     -0.251741           2.455587
# 22  298594  0.16710       9.880384     -0.195829           3.057942
# 23  301906  0.22058       9.815827     -0.235546           2.523152
# 24  302370  0.12441       9.701066     -0.686193           0.989898
# 25  318790  0.16670       9.831631     -0.224314           2.646765
# 26  318810  0.12911       9.910812     -0.241735           3.091578
# 27  324302  0.16591       9.914498     -0.204233           3.322414
# 28  343900  0.14754       9.903134     -0.245788           3.117775
# 29  361693  0.09424       9.560934     -0.661878           0.643692
# 20     -0.195710           3.108134     12.19        0.003686
# 21     -0.306201           2.267916     13.16        0.007714
# 22     -0.195814           3.024879     14.41        0.002625
# 23     -0.214031           2.660531      8.25        0.009020
# 24     -0.737666           1.413076     16.81        0.002028
# 25     -0.200476           2.751212      8.80        0.005991
# 26     -0.247122           3.123008      3.62        0.055650
# 27     -0.206101           3.302308     14.31        0.011322
# 28     -0.252875           3.074621      8.83        0.012425
# 29     -0.709672           1.366323      8.09        0.007995
# ..           ...                ...       ...             ...
# 57     -0.653549           1.790518     11.86        0.005622
# 58     -0.420717           2.102441      9.96        0.005878
# 59     -1.116016           0.615855     10.68        0.005627
# 60     -0.199746           2.775175     13.80        0.002561
# 61     -0.882527           1.081795     12.56        0.004565
# 62     -0.263093           2.448154      6.30        0.017219
# 63     -0.422651           1.930452     14.62        0.002748
# 64     -0.195800           3.444324     10.71        0.011881
# 65     -0.195882           3.321616      8.93        0.011269
# 66     -0.218490           2.588727      6.67        0.010884
# 67     -0.928418           1.320393      3.84        0.048952
# 68     -0.604664           1.288766     14.41        0.002695
# 69     -0.623285           1.387580     11.92        0.003993
# 70     -0.367725           2.702976     16.40        0.002360
# 71     -0.198661           3.399105     15.97        0.015640
# 72     -0.341868           2.183647      9.64        0.006220
# 73     -0.196541           3.249722     11.99        0.005388
# 74     -0.227621           1.407120      6.61        0.011828
# 75     -0.710085           1.359017     15.36        0.002195
# 76     -0.715734           1.338848     14.69        0.002268
# 77     -0.506803           2.337525      9.16        0.020680
# 78     -0.411869           2.043238     14.40        0.001901
# 79     -0.278544           2.337339     12.80        0.003414
# 80     -0.380188           2.080809     10.84        0.003716
# 81     -0.676079           1.376067     11.70        0.004717
# 82     -0.521816           1.676195     10.93        0.003265
# 83     -0.216097           2.652938     14.93        0.003443
# 84     -0.195955           3.257567      6.56        0.013663
# 85     -0.233511           3.074432      8.89        0.022732
# 86     -0.639258           1.898279     14.72        0.002564
#
# [87 rows x 13 columns]

# %% [markdown]
# # Analyses

# %%
fontsize = 15

# %%
plt.plot(out_m230['S2N_runz'], out_m230['CHI2_PPXF_m230'], 'o')
plt.xlabel('S/N (runz)', fontsize=fontsize)
plt.ylabel(r"pPXF $\chi^2$", fontsize=fontsize)
plt.tick_params(axis='both', labelsize=fontsize)
plt.show()

# %%
top_s2n_runz   = mega_dataframe.loc[mega_dataframe['S2N_runz']>10]
worst_s2n_runz = mega_dataframe.loc[mega_dataframe['S2N_runz']<10]

# %%
top_s2n_runz.values.shape
# Out:
# (52, 13)

# %%
worst_s2n_runz.values.shape
# Out:
# (35, 13)

# %%
plt.plot(top_s2n_runz['S2N_runz'], top_s2n_runz['CHI2_PPXF_m230'], 'o')
plt.plot(worst_s2n_runz['S2N_runz'], worst_s2n_runz['CHI2_PPXF_m230'], 'o')
plt.xlabel('S/N (runz)', fontsize=fontsize)
plt.ylabel(r"pPXF $\chi^2$", fontsize=fontsize)
plt.tick_params(axis='both', labelsize=fontsize)
plt.show()

# %%
figsize = (10,5)
pal_top = ['#edf8b1','#7fcdbb','#2c7fb8']
pal_wst = ['#fee8c8','#fdbb84','#e34a33']
alpha = 0.7
xlim = [7.5, 10.5]
ylim = [-1.2, 0.0]

# %%
plt.subplots(figsize=figsize)

ax1 = plt.subplot(1, 3, 1)
plt.plot(top_s2n_runz['<logAge>_m150'], top_s2n_runz['<[M/H]>_m150'], 'o', color=pal_top[2], alpha=alpha)
plt.plot(worst_s2n_runz['<logAge>_m150'], worst_s2n_runz['<[M/H]>_m150'], 'o', color=pal_wst[2], alpha=alpha)
# plt.xlabel(r"<$\log$ t>", fontsize=fontsize)
plt.ylabel(r"<$[M/H]$>", fontsize=fontsize)
plt.tick_params('both', labelsize=fontsize)
plt.title("mdegree=150", fontsize=fontsize)
plt.xlim(xlim)
plt.ylim(ylim)

ax2 = plt.subplot(1, 3, 2, sharey=ax1)
plt.plot(top_s2n_runz['<logAge>_m200'], top_s2n_runz['<[M/H]>_m200'], 'o', color=pal_top[2], alpha=alpha)
plt.plot(worst_s2n_runz['<logAge>_m200'], worst_s2n_runz['<[M/H]>_m200'], 'o', color=pal_wst[2], alpha=alpha)
plt.xlabel(r"<$\log$ t>", fontsize=fontsize)
plt.tick_params('both', labelsize=fontsize)
plt.title("mdegree=200", fontsize=fontsize)
plt.xlim(xlim)
plt.ylim(ylim)
ax2.yaxis.set_visible(False)

ax3 = plt.subplot(1, 3, 3, sharey=ax1)
plt.plot(top_s2n_runz['<logAge>_m230'], top_s2n_runz['<[M/H]>_m230'], 'o', color=pal_top[2], alpha=alpha)
plt.plot(worst_s2n_runz['<logAge>_m230'], worst_s2n_runz['<[M/H]>_m230'], 'o', color=pal_wst[2], alpha=alpha)
# plt.xlabel(r"<$\log$ t>", fontsize=fontsize)
plt.tick_params('both', labelsize=fontsize)
plt.title("mdegree=230", fontsize=fontsize)
plt.xlim(xlim)
plt.ylim(ylim)
ax3.yaxis.set_visible(False)

plt.savefig(os.path.join(outputs_path, 'Analyses_mdegrees/mdegs_logage_metallicity.png')+'age_met.png')

plt.tight_layout()
plt.show()

# %%
top_s2n_runz.describe()
# Out:
#              CATAID          Z  <logAge>_m150  <[M/H]>_m150  \
# count  5.200000e+01  52.000000      52.000000     52.000000
# mean   7.197870e+05   0.177864       9.781376     -0.367402
# std    1.197380e+06   0.049893       0.275779      0.239307
# min    1.492200e+04   0.069390       7.918664     -1.090771
# 25%    8.544975e+04   0.146455       9.789295     -0.439788
# 50%    2.815525e+05   0.173165       9.819948     -0.242787
# 75%    5.604085e+05   0.204440       9.874692     -0.196804
# max    3.909928e+06   0.285410       9.938464     -0.195558
#
#        MASS2LIGHT_R_m150  <logAge>_m200  <[M/H]>_m200  MASS2LIGHT_R_m200  \
# count          52.000000      52.000000     52.000000          52.000000
# mean            2.374954       9.796906     -0.394531           2.266834
# std             0.801477       0.101044      0.237054           0.787781
# min             0.159384       9.449383     -0.965862           0.614567
# 25%             2.060040       9.749378     -0.607324           1.613197
# 50%             2.546413       9.815414     -0.259828           2.429223
# 75%             2.989066       9.868570     -0.197207           2.905856
# max             3.555771       9.937204     -0.195720           3.543896
#
#        <logAge>_m230  <[M/H]>_m230  MASS2LIGHT_R_m230   S2N_runz  \
# count      52.000000     52.000000          52.000000  52.000000
# mean        9.781406     -0.415955           2.226652  13.402500
# std         0.146023      0.240981           0.805603   2.014901
# min         9.023989     -1.116016           0.303782  10.470000
# 25%         9.745781     -0.630823           1.739672  11.905000
# 50%         9.806371     -0.328727           2.367970  13.300000
# 75%         9.864214     -0.199607           2.816346  14.697500
# max         9.935452     -0.195710           3.529004  18.800000
#
#        CHI2_PPXF_m230
# count       52.000000
# mean         0.005260
# std          0.005118
# min          0.001727
# 25%          0.002678
# 50%          0.003854
# 75%          0.005387
# max          0.033891

# %%
worst_s2n_runz.describe()
# Out:
#              CATAID          Z  <logAge>_m150  <[M/H]>_m150  \
# count  3.500000e+01  35.000000      35.000000     35.000000
# mean   4.643476e+05   0.183218       9.796499     -0.332290
# std    8.142470e+05   0.048578       0.154339      0.213063
# min    6.840000e+03   0.094240       9.268779     -1.110748
# 25%    6.982050e+04   0.154970       9.808571     -0.375234
# 50%    3.019060e+05   0.179480       9.833256     -0.231875
# 75%    5.344450e+05   0.209625       9.883369     -0.196379
# max    3.617808e+06   0.294940       9.930840     -0.189704
#
#        MASS2LIGHT_R_m150  <logAge>_m200  <[M/H]>_m200  MASS2LIGHT_R_m200  \
# count          35.000000      35.000000     35.000000          35.000000
# mean            2.435278       9.789894     -0.392894           2.340176
# std             0.828791       0.173985      0.248083           0.835017
# min             0.610043       8.984346     -1.118519           0.404648
# 25%             2.130017       9.780956     -0.578666           1.814036
# 50%             2.672446       9.826862     -0.244269           2.565318
# 75%             3.082144       9.884230     -0.201528           3.072360
# max             3.486933       9.929155     -0.193603           3.471877
#
#        <logAge>_m230  <[M/H]>_m230  MASS2LIGHT_R_m230  S2N_runz  \
# count      35.000000     35.000000          35.000000  35.00000
# mean        9.818729     -0.351413           2.428814   7.44800
# std         0.093024      0.200049           0.703269   1.72539
# min         9.463610     -0.928418           1.014836   3.48000
# 25%         9.783029     -0.513605           2.004507   6.60000
# 50%         9.831773     -0.237856           2.588727   7.68000
# 75%         9.879450     -0.200467           3.049988   8.87500
# max         9.929535     -0.190977           3.474813   9.96000
#
#        CHI2_PPXF_m230
# count       35.000000
# mean         0.016771
# std          0.012393
# min          0.005878
# 25%          0.008537
# 50%          0.012425
# 75%          0.019929
# max          0.055650

# %%
top_s2n_runz.to_csv(os.path.join(outputs_path, 'Analyses_mdegrees/topS2N_runz.csv'))

# %%
worst_s2n_runz.to_csv(os.path.join(outputs_path, 'Analyses_mdegrees/worstS2N_runz.csv'))
