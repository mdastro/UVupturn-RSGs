# %%
import pandas as pd

# %%
data = pd.read_csv('../../Catalogue/Match07_smalldoubleclean_emlines.csv')

# %%
data
# Out:
#        CATAID       OBJID_SDSSDR7  ALPHA_J2000  DELTA_J2000  KRON_RADIUS  \
# 0      585610  588848899914268877     183.6357    -0.180381         3.50
# 1      585622  588848899914334317     183.7372    -0.046642         3.50
# 2      585630  588848899914334392     183.8403    -0.045170         3.50
# 3      585637  588848899914334460     183.7989    -0.059996         3.50
# 4      585667  588848899914399953     183.8874    -0.076773         3.50
# 5      585678  588848899914400032     183.9303    -0.187528         3.50
# 6      585699  588848899914465478     184.1426    -0.183027         3.50
# 7      585760  588848899914531038     184.3120    -0.030468         3.50
# 8      585765  588848899914531072     184.2153    -0.188722         3.50
# 9      586340  588848899914662127     184.5148    -0.165712         3.50
# 10     586349  588848899914662184     184.5967    -0.070609         3.50
# 11     586370  588848899914727574     184.6350    -0.045228         3.50
# ...

# %%
red_sequence = data.loc[data['UV_CLASS_YI2011']!='RSF']

# %%
red_sequence.to_csv('../../Catalogue/red_sequence_all_fromMATCH07.csv')

# %%
sdss = pd.DataFrame(red_sequence['OBJID_SDSSDR7'])

# %%
sdss = sdss.join(red_sequence['ALPHA_J2000']).join(red_sequence['DELTA_J2000'])

# %%
sdss
# Out:
#             OBJID_SDSSDR7  ALPHA_J2000  DELTA_J2000
# 51     588848899929080146     217.5533    -0.056942
# 122    588848899931242710     222.3814    -0.031320
# 126    588848899931439415     222.9286    -0.152468
# 136    588848900427481399     129.5402     0.382411
# 188    588848900429578535     134.3863     0.325479
# 204    588848900431282478     138.2987     0.273487
# 243    588848900447207626     174.6825     0.215878
# 257    588848900447469792     175.2976     0.220674
# 278    588848900448452756     177.4558     0.352174
# 281    588848900448649402     177.9492     0.331941
# 289    588848900449370284     179.6213     0.360711
# 299    588848900449566880     180.0025     0.358867
# 307    588848900449632462     180.2054     0.211046
# 331    588848900450156560     181.3463     0.412290
# 364    588848900451008632     183.3186     0.216772
# 369    588848900451074179     183.5035     0.412270
# 397    588848900451729571     184.9863     0.240714
# ...

# %%
sdss.to_csv('../../Unsorted/red_sequence_sdssdr7_fromMATCH07.csv', index=False)

# %%
for i in range(sdss['ALPHA_J2000'].values.size):
    print (sdss['ALPHA_J2000'].values[i],',', sdss['DELTA_J2000'].values[i], ',', '0.5')
# Out:
# 217.5533 , -0.0569418 , 0.5
# 222.3814 , -0.031319900000000005 , 0.5
# 222.9286 , -0.1524679 , 0.5
# 129.5402 , 0.3824107 , 0.5
# 134.3863 , 0.3254785 , 0.5
# 138.2987 , 0.2734868 , 0.5
# 174.6825 , 0.2158779 , 0.5
# 175.2976 , 0.2206739 , 0.5
# 177.4558 , 0.3521739 , 0.5
# 177.9492 , 0.3319413 , 0.5
# 179.6213 , 0.3607108 , 0.5
# 180.0025 , 0.3588666 , 0.5
# 180.2054 , 0.21104570000000003 , 0.5
# 181.3463 , 0.4122896 , 0.5
# 183.3186 , 0.21677249999999998 , 0.5
# 183.5035 , 0.4122696 , 0.5
# 184.9863 , 0.2407145 , 0.5
# 185.266 , 0.3065122 , 0.5
# 211.7044 , 0.2584618 , 0.5
# 213.6268 , 0.21299520000000002 , 0.5
# 218.4058 , 0.3030025 , 0.5
# 218.7929 , 0.3682033 , 0.5
# 220.5474 , 0.2438862 , 0.5
# 222.9708 , 0.2461641 , 0.5
# 129.8609 , 0.7116634 , 0.5
# 133.8524 , 0.6691094 , 0.5
# 140.2268 , 0.735974 , 0.5
# 174.3469 , 0.6965021 , 0.5
# 177.155 , 0.7812853 , 0.5
# 180.08700000000002 , 0.7630577 , 0.5
# 180.2942 , 0.6462038 , 0.5
# 213.2197 , 0.7977758 , 0.5
# ...

# %%
sdss['ALPHA_J2000'].values.size
# Out:
# 506

# %%
import numpy as np

# %%
coords_search = pd.DataFrame(sdss['ALPHA_J2000']).join(pd.DataFrame(sdss['DELTA_J2000']))

# %%
coords_search['ALPHA_J2000'].columns = 'ra'

# %%
coords_search
# Out:
#        ALPHA_J2000  DELTA_J2000
# 51        217.5533    -0.056942
# 122       222.3814    -0.031320
# 126       222.9286    -0.152468
# 136       129.5402     0.382411
# 188       134.3863     0.325479
# 204       138.2987     0.273487
# 243       174.6825     0.215878
# 257       175.2976     0.220674
# 278       177.4558     0.352174
# 281       177.9492     0.331941
# 289       179.6213     0.360711
# 299       180.0025     0.358867
# 307       180.2054     0.211046
# 331       181.3463     0.412290
# 364       183.3186     0.216772
# 369       183.5035     0.412270
# 397       184.9863     0.240714
# 398       185.2660     0.306512
# 415       211.7044     0.258462
# 463       213.6268     0.212995
# 563       218.4058     0.303003
# 575       218.7929     0.368203
# 652       220.5474     0.243886
# 732       222.9708     0.246164
# 756       129.8609     0.711663
# 767       133.8524     0.669109
# 803       140.2268     0.735974
# 818       174.3469     0.696502
# ...

# %%
coords_search.to_csv('../../Catalogue/red_sequence_all_fromMATCH07_radec.csv', index=False)
